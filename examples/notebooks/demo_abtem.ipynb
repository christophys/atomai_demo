# %%
import abtem
import ase

# %%
file_name="PbCNH6I3.cif"
structure = ase.io.read(file_name)
abtem.show_atoms(structure, plane="xy", legend=True);

# %%
# Source of the data set in this demo 
entry_id = "Y1LROCbYx-k1_-wQc_vQGSbWtwsY"
upload_id = "hCtYZBKeSWS092G0KbtW6w"
NOMAD_url = "http://nomad-lab.eu/prod/rae/api/raw/calc/"
url = NOMAD_url+upload_id+"/"+entry_id
print(f"URL: {url}")
